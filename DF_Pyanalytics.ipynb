# %% [markdown]
# DataSet

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import statsmodels as sm

# %%
# !unzip /content/globalyoutubestatistics2023.zip
# Out:
# Archive:  /content/globalyoutubestatistics2023.zip
# replace Global YouTube Statistics.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
df = pd.read_csv('/content/Global YouTube Statistics.csv', encoding='latin1')

# %%
df
# Out:
#      rank                    Youtuber  subscribers   video views  \
# 0       1                    T-Series    245000000  2.280000e+11
# 1       2              YouTube Movies    170000000  0.000000e+00
# 2       3                     MrBeast    166000000  2.836884e+10
# 3       4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4       5                   SET India    159000000  1.480000e+11
# ..    ...                         ...          ...           ...
# 990   991               Natan por Aï¿     12300000  9.029610e+09
# 991   992    Free Fire India Official     12300000  1.674410e+09
# 992   993                       Panda     12300000  2.214684e+09
# 993   994                 RobTopGames     12300000  3.741235e+08
# 994   995                Make Joke Of     12300000  2.129774e+09
#
#              category                       Title  uploads         Country  \
# 0               Music                    T-Series    20082           India
# 1    Film & Animation               youtubemovies        1   United States
# 2       Entertainment                     MrBeast      741   United States
# 3           Education  Cocomelon - Nursery Rhymes      966   United States
# 4               Shows                   SET India   116536           India
# ..                ...                         ...      ...             ...
# 990            Sports               Natan por Aï¿     1200          Brazil
# 991    People & Blogs    Free Fire India Official     1500           India
# 992               NaN                 HybridPanda     2452  United Kingdom
# 993            Gaming                 RobTopGames       39          Sweden
# 994            Comedy                Make Joke Of       62           India
#
#     Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 0             IN          Music  ...                     2000000.0
# 1             US          Games  ...                           NaN
# 2             US  Entertainment  ...                     8000000.0
# 3             US      Education  ...                     1000000.0
# 4             IN  Entertainment  ...                     1000000.0
# ..           ...            ...  ...                           ...
# 990           BR  Entertainment  ...                      700000.0
# 991           IN          Games  ...                      300000.0
# 992           GB          Games  ...                        1000.0
# 993           SE          Games  ...                      100000.0
# 994           IN         Comedy  ...                      100000.0
#
#      created_year  created_month  created_date  \
# 0          2006.0            Mar          13.0
# 1          2006.0            Mar           5.0
# 2          2012.0            Feb          20.0
# 3          2006.0            Sep           1.0
# 4          2006.0            Sep          20.0
# ..            ...            ...           ...
# 990        2017.0            Feb          12.0
# 991        2018.0            Sep          14.0
# 992        2006.0            Sep          11.0
# 993        2012.0            May           9.0
# 994        2017.0            Aug           1.0
#
#      Gross tertiary education enrollment (%)    Population  Unemployment rate  \
# 0                                       28.1  1.366418e+09               5.36
# 1                                       88.2  3.282395e+08              14.70
# 2                                       88.2  3.282395e+08              14.70
# 3                                       88.2  3.282395e+08              14.70
# 4                                       28.1  1.366418e+09               5.36
# ..                                       ...           ...                ...
# 990                                     51.3  2.125594e+08              12.08
# 991                                     28.1  1.366418e+09               5.36
# 992                                     60.0  6.683440e+07               3.85
# 993                                     67.0  1.028545e+07               6.48
# 994                                     28.1  1.366418e+09               5.36
#
#      Urban_population   Latitude  Longitude
# 0         471031528.0  20.593684  78.962880
# 1         270663028.0  37.090240 -95.712891
# 2         270663028.0  37.090240 -95.712891
# 3         270663028.0  37.090240 -95.712891
# 4         471031528.0  20.593684  78.962880
# ..                ...        ...        ...
# 990       183241641.0 -14.235004 -51.925280
# 991       471031528.0  20.593684  78.962880
# 992        55908316.0  55.378051  -3.435973
# 993         9021165.0  60.128161  18.643501
# 994       471031528.0  20.593684  78.962880
#
# [995 rows x 28 columns]

# %%
#considerando a ideia de que canais que foram criados antes de 2015 sejam canais antigos do youtube e canais que foram criados deste momento para cá
#sejam considerados recentes...
df['isAntigoouRecente'] = np.where(df['created_year']<2015, 'Antigo', 'Recente')

# %%
df
# Out:
#      rank                    Youtuber  subscribers   video views  \
# 0       1                    T-Series    245000000  2.280000e+11
# 1       2              YouTube Movies    170000000  0.000000e+00
# 2       3                     MrBeast    166000000  2.836884e+10
# 3       4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4       5                   SET India    159000000  1.480000e+11
# ..    ...                         ...          ...           ...
# 990   991               Natan por Aï¿     12300000  9.029610e+09
# 991   992    Free Fire India Official     12300000  1.674410e+09
# 992   993                       Panda     12300000  2.214684e+09
# 993   994                 RobTopGames     12300000  3.741235e+08
# 994   995                Make Joke Of     12300000  2.129774e+09
#
#              category                       Title  uploads         Country  \
# 0               Music                    T-Series    20082           India
# 1    Film & Animation               youtubemovies        1   United States
# 2       Entertainment                     MrBeast      741   United States
# 3           Education  Cocomelon - Nursery Rhymes      966   United States
# 4               Shows                   SET India   116536           India
# ..                ...                         ...      ...             ...
# 990            Sports               Natan por Aï¿     1200          Brazil
# 991    People & Blogs    Free Fire India Official     1500           India
# 992               NaN                 HybridPanda     2452  United Kingdom
# 993            Gaming                 RobTopGames       39          Sweden
# 994            Comedy                Make Joke Of       62           India
#
#     Abbreviation   channel_type  ...  created_year  created_month  \
# 0             IN          Music  ...        2006.0            Mar
# 1             US          Games  ...        2006.0            Mar
# 2             US  Entertainment  ...        2012.0            Feb
# 3             US      Education  ...        2006.0            Sep
# 4             IN  Entertainment  ...        2006.0            Sep
# ..           ...            ...  ...           ...            ...
# 990           BR  Entertainment  ...        2017.0            Feb
# 991           IN          Games  ...        2018.0            Sep
# 992           GB          Games  ...        2006.0            Sep
# 993           SE          Games  ...        2012.0            May
# 994           IN         Comedy  ...        2017.0            Aug
#
#      created_date  Gross tertiary education enrollment (%)    Population  \
# 0            13.0                                     28.1  1.366418e+09
# 1             5.0                                     88.2  3.282395e+08
# 2            20.0                                     88.2  3.282395e+08
# 3             1.0                                     88.2  3.282395e+08
# 4            20.0                                     28.1  1.366418e+09
# ..            ...                                      ...           ...
# 990          12.0                                     51.3  2.125594e+08
# 991          14.0                                     28.1  1.366418e+09
# 992          11.0                                     60.0  6.683440e+07
# 993           9.0                                     67.0  1.028545e+07
# 994           1.0                                     28.1  1.366418e+09
#
#      Unemployment rate  Urban_population   Latitude  Longitude  \
# 0                 5.36       471031528.0  20.593684  78.962880
# 1                14.70       270663028.0  37.090240 -95.712891
# 2                14.70       270663028.0  37.090240 -95.712891
# 3                14.70       270663028.0  37.090240 -95.712891
# 4                 5.36       471031528.0  20.593684  78.962880
# ..                 ...               ...        ...        ...
# 990              12.08       183241641.0 -14.235004 -51.925280
# 991               5.36       471031528.0  20.593684  78.962880
# 992               3.85        55908316.0  55.378051  -3.435973
# 993               6.48         9021165.0  60.128161  18.643501
# 994               5.36       471031528.0  20.593684  78.962880
#
#      isAntigoouRecente
# 0               Antigo
# 1               Antigo
# 2               Antigo
# 3               Antigo
# 4               Antigo
# ..                 ...
# 990            Recente
# 991            Recente
# 992             Antigo
# 993             Antigo
# 994            Recente
#
# [995 rows x 29 columns]

# %%
#contar quantas linhas tem para depois ver se tem duplicadas
df.count()
# Out:
# rank                                       995
# Youtuber                                   995
# subscribers                                995
# video views                                995
# category                                   949
# Title                                      995
# uploads                                    995
# Country                                    873
# Abbreviation                               873
# channel_type                               965
# video_views_rank                           994
# country_rank                               879
# channel_type_rank                          962
# video_views_for_the_last_30_days           939
# lowest_monthly_earnings                    995
# highest_monthly_earnings                   995
# lowest_yearly_earnings                     995
# highest_yearly_earnings                    995
# subscribers_for_last_30_days               658
# created_year                               990
# created_month                              990
# created_date                               990
# Gross tertiary education enrollment (%)    872
# Population                                 872
# Unemployment rate                          872
# Urban_population                           872
# Latitude                                   872
# Longitude                                  872
# isAntigoouRecente                          995
# dtype: int64

# %%
df.columns = df.columns.str.lower()

# %%
df.head(10)
# Out:
#    rank                    youtuber  subscribers   video views  \
# 0     1                    T-Series    245000000  2.280000e+11
# 1     2              YouTube Movies    170000000  0.000000e+00
# 2     3                     MrBeast    166000000  2.836884e+10
# 3     4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4     5                   SET India    159000000  1.480000e+11
# 5     6                       Music    119000000  0.000000e+00
# 6     7         ýýý Kids Diana Show    112000000  9.324704e+10
# 7     8                   PewDiePie    111000000  2.905804e+10
# 8     9                 Like Nastya    106000000  9.047906e+10
# 9    10               Vlad and Niki     98900000  7.718017e+10
#
#            category                       title  uploads        country  \
# 0             Music                    T-Series    20082          India
# 1  Film & Animation               youtubemovies        1  United States
# 2     Entertainment                     MrBeast      741  United States
# 3         Education  Cocomelon - Nursery Rhymes      966  United States
# 4             Shows                   SET India   116536          India
# 5               NaN                       Music        0            NaN
# 6    People & Blogs         ýýý Kids Diana Show     1111  United States
# 7            Gaming                   PewDiePie     4716          Japan
# 8    People & Blogs            Like Nastya Vlog      493         Russia
# 9     Entertainment               Vlad and Niki      574  United States
#
#   abbreviation   channel_type  ...  created_year  created_month  created_date  \
# 0           IN          Music  ...        2006.0            Mar          13.0
# 1           US          Games  ...        2006.0            Mar           5.0
# 2           US  Entertainment  ...        2012.0            Feb          20.0
# 3           US      Education  ...        2006.0            Sep           1.0
# 4           IN  Entertainment  ...        2006.0            Sep          20.0
# 5          NaN          Music  ...        2013.0            Sep          24.0
# 6           US  Entertainment  ...        2015.0            May          12.0
# 7           JP  Entertainment  ...        2010.0            Apr          29.0
# 8           RU         People  ...        2016.0            Jan          14.0
# 9           US  Entertainment  ...        2018.0            Apr          23.0
#
#    gross tertiary education enrollment (%)    population  unemployment rate  \
# 0                                     28.1  1.366418e+09               5.36
# 1                                     88.2  3.282395e+08              14.70
# 2                                     88.2  3.282395e+08              14.70
# 3                                     88.2  3.282395e+08              14.70
# 4                                     28.1  1.366418e+09               5.36
# 5                                      NaN           NaN                NaN
# 6                                     88.2  3.282395e+08              14.70
# 7                                     63.2  1.262266e+08               2.29
# 8                                     81.9  1.443735e+08               4.59
# 9                                     88.2  3.282395e+08              14.70
#
#    urban_population   latitude   longitude  isantigoourecente
# 0       471031528.0  20.593684   78.962880             Antigo
# 1       270663028.0  37.090240  -95.712891             Antigo
# 2       270663028.0  37.090240  -95.712891             Antigo
# 3       270663028.0  37.090240  -95.712891             Antigo
# 4       471031528.0  20.593684   78.962880             Antigo
# 5               NaN        NaN         NaN             Antigo
# 6       270663028.0  37.090240  -95.712891            Recente
# 7       115782416.0  36.204824  138.252924             Antigo
# 8       107683889.0  61.524010  105.318756            Recente
# 9       270663028.0  37.090240  -95.712891            Recente
#
# [10 rows x 29 columns]

# %%
df.dtypes
# Out:
# rank                                         int64
# youtuber                                    object
# subscribers                                  int64
# video views                                float64
# category                                    object
# title                                       object
# uploads                                      int64
# country                                     object
# abbreviation                                object
# channel_type                                object
# video_views_rank                           float64
# country_rank                               float64
# channel_type_rank                          float64
# video_views_for_the_last_30_days           float64
# lowest_monthly_earnings                    float64
# highest_monthly_earnings                   float64
# lowest_yearly_earnings                     float64
# highest_yearly_earnings                    float64
# subscribers_for_last_30_days               float64
# created_year                               float64
# created_month                               object
# created_date                               float64
# gross tertiary education enrollment (%)    float64
# population                                 float64
# unemployment rate                          float64
# urban_population                           float64
# latitude                                   float64
# longitude                                  float64
# isantigoourecente                           object
# dtype: object

# %%
df['country'].value_counts()
# Out:
# United States           313
# India                   168
# Brazil                   62
# United Kingdom           43
# Mexico                   33
# Indonesia                28
# Spain                    22
# Thailand                 18
# South Korea              17
# Russia                   16
# Canada                   15
# Argentina                13
# Philippines              12
# Colombia                 11
# Australia                 9
# Saudi Arabia              9
# Ukraine                   8
# United Arab Emirates      7
# Germany                   6
# Pakistan                  6
# France                    5
# Japan                     5
# Turkey                    4
# Sweden                    4
# Vietnam                   3
# Jordan                    3
# Netherlands               3
# Singapore                 3
# Chile                     3
# Egypt                     2
# Ecuador                   2
# Iraq                      2
# Italy                     2
# China                     1
# Peru                      1
# Andorra                   1
# Bangladesh                1
# Finland                   1
# Morocco                   1
# Kuwait                    1
# Malaysia                  1
# Switzerland               1
# Latvia                    1
# Afghanistan               1
# Venezuela                 1
# Barbados                  1
# El Salvador               1
# Cuba                      1
# Samoa                     1
# Name: country, dtype: int64

# %%
df['category'].value_counts()
# Out:
# Entertainment            241
# Music                    202
# People & Blogs           132
# Gaming                    94
# Comedy                    69
# Film & Animation          46
# Education                 45
# Howto & Style             40
# News & Politics           26
# Science & Technology      17
# Shows                     13
# Sports                    11
# Pets & Animals             4
# Trailers                   2
# Nonprofits & Activism      2
# Movies                     2
# Autos & Vehicles           2
# Travel & Events            1
# Name: category, dtype: int64

# %%
df[(df['subscribers']>5000000) & (df['country'] == 'Brazil')]
# Out:
#      rank           youtuber  subscribers   video views       category  \
# 23     24    Canal KondZilla     66500000  3.677559e+10          Music
# 54     55        Felipe Neto     45200000  1.660220e+10  Entertainment
# 55     56       Vocï¿½ï¿½ï¿½     44700000  7.828611e+09  Entertainment
# 59     60   whinderssonnunes     44200000  4.274709e+09         Comedy
# 83     84        GR6 EXPLODE     38900000  2.515423e+10          Music
# ..    ...                ...          ...           ...            ...
# 940   941           Piuzinho     12700000  1.081286e+09         Gaming
# 959   960       Parafernalha     12500000  4.625778e+09  Entertainment
# 965   966         Mundo Bita     12500000  1.669079e+10          Music
# 975   976  Gustavo Parï¿½ï¿½     12400000  2.602614e+09         Comedy
# 990   991      Natan por Aï¿     12300000  9.029610e+09         Sports
#
#                 title  uploads country abbreviation   channel_type  ...  \
# 23    Canal KondZilla     2572  Brazil           BR          Music  ...
# 54        Felipe Neto     4331  Brazil           BR  Entertainment  ...
# 55       Vocï¿½ï¿½ï¿½     1558  Brazil           BR  Entertainment  ...
# 59   whinderssonnunes      558  Brazil           BR         Comedy  ...
# 83        GR6 EXPLODE     3043  Brazil           BR          Music  ...
# ..                ...      ...     ...          ...            ...  ...
# 940          Piuzinho      504  Brazil           BR          Games  ...
# 959      Parafernalha     1888  Brazil           BR  Entertainment  ...
# 965        Mundo Bita      253  Brazil           BR          Music  ...
# 975   GustavoParodias        9  Brazil           BR         Comedy  ...
# 990     Natan por Aï¿     1200  Brazil           BR  Entertainment  ...
#
#      created_year  created_month  created_date  \
# 23         2012.0            Mar          21.0
# 54         2006.0            May          16.0
# 55         2013.0            Sep           1.0
# 59         2013.0            Jan          21.0
# 83         2014.0            Aug           5.0
# ..            ...            ...           ...
# 940        2015.0            May          13.0
# 959        2011.0            May          13.0
# 965        2011.0            Sep          29.0
# 975        2010.0            Aug          24.0
# 990        2017.0            Feb          12.0
#
#      gross tertiary education enrollment (%)   population  unemployment rate  \
# 23                                      51.3  212559417.0              12.08
# 54                                      51.3  212559417.0              12.08
# 55                                      51.3  212559417.0              12.08
# 59                                      51.3  212559417.0              12.08
# 83                                      51.3  212559417.0              12.08
# ..                                       ...          ...                ...
# 940                                     51.3  212559417.0              12.08
# 959                                     51.3  212559417.0              12.08
# 965                                     51.3  212559417.0              12.08
# 975                                     51.3  212559417.0              12.08
# 990                                     51.3  212559417.0              12.08
#
#      urban_population   latitude  longitude  isantigoourecente
# 23        183241641.0 -14.235004  -51.92528             Antigo
# 54        183241641.0 -14.235004  -51.92528             Antigo
# 55        183241641.0 -14.235004  -51.92528             Antigo
# 59        183241641.0 -14.235004  -51.92528             Antigo
# 83        183241641.0 -14.235004  -51.92528             Antigo
# ..                ...        ...        ...                ...
# 940       183241641.0 -14.235004  -51.92528            Recente
# 959       183241641.0 -14.235004  -51.92528             Antigo
# 965       183241641.0 -14.235004  -51.92528             Antigo
# 975       183241641.0 -14.235004  -51.92528             Antigo
# 990       183241641.0 -14.235004  -51.92528            Recente
#
# [62 rows x 29 columns]

# %%
#contar quantas linhas tem para depois ver se tem duplicadas
df.count()
# Out:
# rank                                       995
# youtuber                                   995
# subscribers                                995
# video views                                995
# category                                   949
# title                                      995
# uploads                                    995
# country                                    873
# abbreviation                               873
# channel_type                               965
# video_views_rank                           994
# country_rank                               879
# channel_type_rank                          962
# video_views_for_the_last_30_days           939
# lowest_monthly_earnings                    995
# highest_monthly_earnings                   995
# lowest_yearly_earnings                     995
# highest_yearly_earnings                    995
# subscribers_for_last_30_days               658
# created_year                               990
# created_month                              990
# created_date                               990
# gross tertiary education enrollment (%)    872
# population                                 872
# unemployment rate                          872
# urban_population                           872
# latitude                                   872
# longitude                                  872
# isantigoourecente                          995
# dtype: int64

# %%
df.drop_duplicates(subset=['youtuber'], keep= 'first', inplace=True)

# %%
#quero ver as coisas que são nulas nesse dataframe
df.isnull()
# Out:
#       rank  youtuber  subscribers  video views  category  title  uploads  \
# 0    False     False        False        False     False  False    False
# 1    False     False        False        False     False  False    False
# 2    False     False        False        False     False  False    False
# 3    False     False        False        False     False  False    False
# 4    False     False        False        False     False  False    False
# ..     ...       ...          ...          ...       ...    ...      ...
# 990  False     False        False        False     False  False    False
# 991  False     False        False        False     False  False    False
# 992  False     False        False        False      True  False    False
# 993  False     False        False        False     False  False    False
# 994  False     False        False        False     False  False    False
#
#      country  abbreviation  channel_type  ...  created_year  created_month  \
# 0      False         False         False  ...         False          False
# 1      False         False         False  ...         False          False
# 2      False         False         False  ...         False          False
# 3      False         False         False  ...         False          False
# 4      False         False         False  ...         False          False
# ..       ...           ...           ...  ...           ...            ...
# 990    False         False         False  ...         False          False
# 991    False         False         False  ...         False          False
# 992    False         False         False  ...         False          False
# 993    False         False         False  ...         False          False
# 994    False         False         False  ...         False          False
#
#      created_date  gross tertiary education enrollment (%)  population  \
# 0           False                                    False       False
# 1           False                                    False       False
# 2           False                                    False       False
# 3           False                                    False       False
# 4           False                                    False       False
# ..            ...                                      ...         ...
# 990         False                                    False       False
# 991         False                                    False       False
# 992         False                                    False       False
# 993         False                                    False       False
# 994         False                                    False       False
#
#      unemployment rate  urban_population  latitude  longitude  \
# 0                False             False     False      False
# 1                False             False     False      False
# 2                False             False     False      False
# 3                False             False     False      False
# 4                False             False     False      False
# ..                 ...               ...       ...        ...
# 990              False             False     False      False
# 991              False             False     False      False
# 992              False             False     False      False
# 993              False             False     False      False
# 994              False             False     False      False
#
#      isantigoourecente
# 0                False
# 1                False
# 2                False
# 3                False
# 4                False
# ..                 ...
# 990              False
# 991              False
# 992              False
# 993              False
# 994              False
#
# [995 rows x 29 columns]

# %%
#agora quero os nulos mas vindo com o nome bonitinho e separado, pq antes tava tudo falso
df.isnull().sum()
# Out:
# rank                                         0
# youtuber                                     0
# subscribers                                  0
# video views                                  0
# category                                    46
# title                                        0
# uploads                                      0
# country                                    122
# abbreviation                               122
# channel_type                                30
# video_views_rank                             1
# country_rank                               116
# channel_type_rank                           33
# video_views_for_the_last_30_days            56
# lowest_monthly_earnings                      0
# highest_monthly_earnings                     0
# lowest_yearly_earnings                       0
# highest_yearly_earnings                      0
# subscribers_for_last_30_days               337
# created_year                                 5
# created_month                                5
# created_date                                 5
# gross tertiary education enrollment (%)    123
# population                                 123
# unemployment rate                          123
# urban_population                           123
# latitude                                   123
# longitude                                  123
# isantigoourecente                            0
# dtype: int64

# %%
#o que for nulo no topico dos inscritos dos ultimos 30 dias será em vez de tirado, colocado como ZERO
df['subscribers_for_last_30_days'] = df['subscribers_for_last_30_days'].fillna('ZERO')

# %%
# Exibir as primeiras linhas do DataFrame para verificar os dados
print(df.head())
# Out:
#    rank                    youtuber  subscribers   video views  \
# 0     1                    T-Series    245000000  2.280000e+11
# 1     2              YouTube Movies    170000000  0.000000e+00
# 2     3                     MrBeast    166000000  2.836884e+10
# 3     4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4     5                   SET India    159000000  1.480000e+11
#
#            category                       title  uploads        country  \
# 0             Music                    T-Series    20082          India
# 1  Film & Animation               youtubemovies        1  United States
# 2     Entertainment                     MrBeast      741  United States
# 3         Education  Cocomelon - Nursery Rhymes      966  United States
# 4             Shows                   SET India   116536          India
#
#   abbreviation   channel_type  ...  created_year  created_month  created_date  \
# 0           IN          Music  ...        2006.0            Mar          13.0
# 1           US          Games  ...        2006.0            Mar           5.0
# 2           US  Entertainment  ...        2012.0            Feb          20.0
# 3           US      Education  ...        2006.0            Sep           1.0
# 4           IN  Entertainment  ...        2006.0            Sep          20.0
#
#    gross tertiary education enrollment (%)    population  unemployment rate  \
# 0                                     28.1  1.366418e+09               5.36
# 1                                     88.2  3.282395e+08              14.70
# 2                                     88.2  3.282395e+08              14.70
# 3                                     88.2  3.282395e+08              14.70
# 4                                     28.1  1.366418e+09               5.36
#
#    urban_population   latitude  longitude  isantigoourecente
# 0       471031528.0  20.593684  78.962880             Antigo
# 1       270663028.0  37.090240 -95.712891             Antigo
# 2       270663028.0  37.090240 -95.712891             Antigo
# 3       270663028.0  37.090240 -95.712891             Antigo
# 4       471031528.0  20.593684  78.962880             Antigo
#
# [5 rows x 29 columns]

# %%
df2 = df[['youtuber', 'country', 'uploads', 'isantigoourecente', 'subscribers_for_last_30_days', 'category']]

# %%
df2
# Out:
#                        youtuber         country  uploads isantigoourecente  \
# 0                      T-Series           India    20082            Antigo
# 1                YouTube Movies   United States        1            Antigo
# 2                       MrBeast   United States      741            Antigo
# 3    Cocomelon - Nursery Rhymes   United States      966            Antigo
# 4                     SET India           India   116536            Antigo
# ..                          ...             ...      ...               ...
# 990               Natan por Aï¿          Brazil     1200           Recente
# 991    Free Fire India Official           India     1500           Recente
# 992                       Panda  United Kingdom     2452            Antigo
# 993                 RobTopGames          Sweden       39            Antigo
# 994                Make Joke Of           India       62           Recente
#
#     subscribers_for_last_30_days          category
# 0                      2000000.0             Music
# 1                           ZERO  Film & Animation
# 2                      8000000.0     Entertainment
# 3                      1000000.0         Education
# 4                      1000000.0             Shows
# ..                           ...               ...
# 990                     700000.0            Sports
# 991                     300000.0    People & Blogs
# 992                       1000.0               NaN
# 993                     100000.0            Gaming
# 994                     100000.0            Comedy
#
# [995 rows x 6 columns]

# %%
df['subscribers_for_last_30_days']
# Out:
# 0      2000000.0
# 1           ZERO
# 2      8000000.0
# 3      1000000.0
# 4      1000000.0
#          ...
# 990     700000.0
# 991     300000.0
# 992       1000.0
# 993     100000.0
# 994     100000.0
# Name: subscribers_for_last_30_days, Length: 995, dtype: object

# %%
#substituindo o zero por "0"
df.loc[df['subscribers_for_last_30_days'] == 'ZERO', 'subscribers_for_last_30_days'] = 0

# %%
#fazer o grafico
fig, ax = plt.subplots()

ax.hist(df['subscribers_for_last_30_days'])
plt.show()

# %%
df3 = df2.groupby('isantigoourecente')['youtuber'].count()
print(df3)
# Out:
# isantigoourecente
# Antigo     635
# Recente    360
# Name: youtuber, dtype: int64

# %%
fig, ax=plt.subplots()
ax.pie(df3, radius=4, center=(4, 4),
wedgeprops={"linewidth": 1, "edgecolor": "white"}, frame=True)

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()

# %%
df2
# Out:
#                        youtuber         country  uploads isantigoourecente  \
# 0                      T-Series           India    20082            Antigo
# 1                YouTube Movies   United States        1            Antigo
# 2                       MrBeast   United States      741            Antigo
# 3    Cocomelon - Nursery Rhymes   United States      966            Antigo
# 4                     SET India           India   116536            Antigo
# ..                          ...             ...      ...               ...
# 990               Natan por Aï¿          Brazil     1200           Recente
# 991    Free Fire India Official           India     1500           Recente
# 992                       Panda  United Kingdom     2452            Antigo
# 993                 RobTopGames          Sweden       39            Antigo
# 994                Make Joke Of           India       62           Recente
#
#     subscribers_for_last_30_days          category
# 0                      2000000.0             Music
# 1                           ZERO  Film & Animation
# 2                      8000000.0     Entertainment
# 3                      1000000.0         Education
# 4                      1000000.0             Shows
# ..                           ...               ...
# 990                     700000.0            Sports
# 991                     300000.0    People & Blogs
# 992                       1000.0               NaN
# 993                     100000.0            Gaming
# 994                     100000.0            Comedy
#
# [995 rows x 6 columns]

# %%
geral_brasil = df2[(df2['country'] == 'Brazil')]

# %%
geral_brasil
# Out:
#               youtuber country  uploads isantigoourecente  \
# 23     Canal KondZilla  Brazil     2572            Antigo
# 54         Felipe Neto  Brazil     4331            Antigo
# 55        Vocï¿½ï¿½ï¿½  Brazil     1558            Antigo
# 59    whinderssonnunes  Brazil      558            Antigo
# 83         GR6 EXPLODE  Brazil     3043            Antigo
# ..                 ...     ...      ...               ...
# 940           Piuzinho  Brazil      504           Recente
# 959       Parafernalha  Brazil     1888            Antigo
# 965         Mundo Bita  Brazil      253            Antigo
# 975  Gustavo Parï¿½ï¿½  Brazil        9            Antigo
# 990      Natan por Aï¿  Brazil     1200           Recente
#
#     subscribers_for_last_30_days       category
# 23                          ZERO          Music
# 54                      200000.0  Entertainment
# 55                      100000.0  Entertainment
# 59                          ZERO         Comedy
# 83                      100000.0          Music
# ..                           ...            ...
# 940                         ZERO         Gaming
# 959                         ZERO  Entertainment
# 965                     100000.0          Music
# 975                         ZERO         Comedy
# 990                     700000.0         Sports
#
# [62 rows x 6 columns]

# %%
canais_de_musica_BR = geral_brasil[(geral_brasil['category'] == 'Music')]

# %%
canais_de_musica_BR
# Out:
#                    youtuber country  uploads isantigoourecente  \
# 23          Canal KondZilla  Brazil     2572            Antigo
# 83              GR6 EXPLODE  Brazil     3043            Antigo
# 405   Gusttavo Lima Oficial  Brazil      416            Antigo
# 455  Dan-Sa / Daniel Saboya  Brazil     1329            Antigo
# 525                  Anitta  Brazil      138            Antigo
# 610                MK MUSIC  Brazil     5105            Antigo
# 633      Henrique e Juliano  Brazil      325            Antigo
# 691    Zï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï  Brazil      340            Antigo
# 709  Jorge & Mateus Oficial  Brazil      318            Antigo
# 724           Camila Loures  Brazil     3978            Antigo
# 731        O Reino Infantil  Brazil     1206            Antigo
# 735            LEGENDA FUNK  Brazil        0           Recente
# 828         Wesley Safadï¿½  Brazil      438            Antigo
# 895         Hungria Hip Hop  Brazil       73            Antigo
# 909               7 Minutoz  Brazil      521            Antigo
# 965              Mundo Bita  Brazil      253            Antigo
#
#     subscribers_for_last_30_days category
# 23                          ZERO    Music
# 83                      100000.0    Music
# 405                     100000.0    Music
# 455                     100000.0    Music
# 525                         ZERO    Music
# 610                     100000.0    Music
# 633                         ZERO    Music
# 691                         ZERO    Music
# 709                         ZERO    Music
# 724                     100000.0    Music
# 731                     100000.0    Music
# 735                         ZERO    Music
# 828                         ZERO    Music
# 895                         ZERO    Music
# 909                         ZERO    Music
# 965                     100000.0    Music

# %%
#Em que tipo de conteúdo os países ou regiões mais focam??
df2['country'].value_counts()
# Out:
# United States           313
# India                   168
# Brazil                   62
# United Kingdom           43
# Mexico                   33
# Indonesia                28
# Spain                    22
# Thailand                 18
# South Korea              17
# Russia                   16
# Canada                   15
# Argentina                13
# Philippines              12
# Colombia                 11
# Australia                 9
# Saudi Arabia              9
# Ukraine                   8
# United Arab Emirates      7
# Germany                   6
# Pakistan                  6
# France                    5
# Japan                     5
# Turkey                    4
# Sweden                    4
# Vietnam                   3
# Jordan                    3
# Netherlands               3
# Singapore                 3
# Chile                     3
# Egypt                     2
# Ecuador                   2
# Iraq                      2
# Italy                     2
# China                     1
# Peru                      1
# Andorra                   1
# Bangladesh                1
# Finland                   1
# Morocco                   1
# Kuwait                    1
# Malaysia                  1
# Switzerland               1
# Latvia                    1
# Afghanistan               1
# Venezuela                 1
# Barbados                  1
# El Salvador               1
# Cuba                      1
# Samoa                     1
# Name: country, dtype: int64

# %%
cat_US = df2[(df2['country'] == 'United States')]
print(cat_US)
# Out:
#                        youtuber        country  uploads isantigoourecente  \
# 1                YouTube Movies  United States        1            Antigo
# 2                       MrBeast  United States      741            Antigo
# 3    Cocomelon - Nursery Rhymes  United States      966            Antigo
# 6           ýýý Kids Diana Show  United States     1111           Recente
# 9                 Vlad and Niki  United States      574           Recente
# ..                          ...            ...      ...               ...
# 973                        LOUD  United States      690            Antigo
# 983                    MoniLina  United States        0           Recente
# 987               Avril Lavigne  United States      205            Antigo
# 988                      Caylus  United States     1340           Recente
# 989                   Migos ATL  United States       99            Antigo
#
#     subscribers_for_last_30_days          category
# 1                           ZERO  Film & Animation
# 2                      8000000.0     Entertainment
# 3                      1000000.0         Education
# 6                           ZERO    People & Blogs
# 9                       600000.0     Entertainment
# ..                           ...               ...
# 973                         ZERO            Gaming
# 983                        100.0            Comedy
# 987                         ZERO             Music
# 988                     400000.0         Education
# 989                     100000.0             Music
#
# [313 rows x 6 columns]

# %%
catg_US = cat_US.groupby('category')['youtuber'].count()

# %% [markdown]
# A proporção parece estar errada, pq tinha uma categoria com Entertainment            68
# e
# People & Blogs           38
# como a segunda maior

# %%
sns.countplot(cat_US, y='category')
# Out:
# <Axes: xlabel='count', ylabel='category'>

# %%
#depois fazer a soma das categorias com o numero de visualizações para ver qual a cateogria mais assistida, somando as duas com algum comando
plt.hist(catg_US, bins=20, edgecolor='black')

#adicionar titulos
plt.xlabel('category')

plt.title('Histograma das categorias USA')

plt.show()

# %%
import plotly.express as px

# %%
fig = px.scatter(cat_US, x='uploads', y= 'subscribers_for_last_30_days')

#botando o tutulo e os eixos
fig.update_layout(title = 'Gráfico de relação entre uploads e taxa de inscritos por canal')
fig.update_yaxes(title = 'Incritos no último mês')

#mostrar
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="4c6ee868-32a0-4e9e-bc9f-63e3db4a0127" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4c6ee868-32a0-4e9e-bc9f-63e3db4a0127")) {                    Plotly.newPlot(                        "4c6ee868-32a0-4e9e-bc9f-63e3db4a0127",                        [{"hovertemplate":"uploads=%{x}\u003cbr\u003esubscribers_for_last_30_days=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"h","showlegend":false,"x":[1,741,966,1111,574,70127,3,2865,389,39113,156,436,216,147,847,65,3444,128,1218,618,2423,133,200933,11,15672,505,515,743,99,171,744,5490,2453,617,3366,188,2122,2068,166,116,1321,204,8976,92,578,2725,532,223,2,1349,4903,1513,5809,15,27,682,642,5438,554,241,6471,6873,865,775,1619,240,749,42,287,78,8775,2025,118,1894,104,175,120,658,36,252,590,4009,505,257,511,2425,443,1732,769,719,552,3657,1,172,4445,3781,0,985,180,171,2321,526,3315,1724,999,157,515,301,946,816,257,10162,228,51,733,78,1608,4728,403,420,498,982,9850,6,619,5062,47926,296,1006,761,3774,241,1481,2384,5491,1,7737,4339,1527,760,9930,250,1,17,18661,214,674,570,6526,139,60,2072,217,457,111,197,142,1324,420,707,45,237,5692,536,982,185,314,830,1426,26,178,156215,4411,180,1567,142,97,1910,366,3900,2337,1693,920,13,413,421,438,735,1091,14662,54,490,80,352,989,258,593,189,510,671,4045,2035,433,796,10441,7090,4245,0,417,1647,1756,21,851,160405,210,1037,2618,1362,0,20292,5198,1803,419,86,127,1210,1481,195,233,2222,3867,85,317,698,4340,1996,80830,1244,4009,365,67,479,453,1717,605,19201,147,463,450,1248,0,516,186,576,1,1724,43,182,41117,183,503,1660,504,369,173,412,199,8335,321,462,477,1349,3727,319,96,8195,331,698,3166,2742,4613,6916,538,4279,6888,33,289,435,194,716,612,1598,39,137,681,168,534,119,142,812,600,1101,99,601,61,1076,322,398,690,0,205,1340,99],"xaxis":"x","y":["ZERO",8000000.0,1000000.0,"ZERO",600000.0,600000.0,"ZERO",600000.0,100000.0,100000.0,300000.0,100000.0,800000.0,100000.0,600000.0,200000.0,400000.0,100000.0,1000000.0,"ZERO",100000.0,100000.0,100000.0,100.0,"ZERO",100000.0,200000.0,700000.0,200000.0,"ZERO",300000.0,100000.0,200000.0,300000.0,200000.0,200000.0,200000.0,300000.0,200000.0,200000.0,400000.0,"ZERO",100000.0,100000.0,200000.0,"ZERO",300000.0,"ZERO","ZERO","ZERO","ZERO",1000000.0,"ZERO",200000.0,"ZERO",100000.0,400000.0,200000.0,300000.0,1200000.0,200000.0,"ZERO",1300000.0,200000.0,400000.0,"ZERO",100000.0,100000.0,100000.0,100000.0,600000.0,300000.0,"ZERO",400000.0,100000.0,100000.0,200000.0,400000.0,100000.0,"ZERO",200000.0,200000.0,100000.0,"ZERO",300000.0,100000.0,100000.0,"ZERO",1100000.0,"ZERO",400000.0,100000.0,100000.0,100000.0,100000.0,700000.0,1.0,300000.0,100000.0,"ZERO",1300000.0,100000.0,200000.0,100000.0,200000.0,100000.0,200000.0,500000.0,400000.0,1900000.0,600000.0,100000.0,"ZERO",200000.0,200000.0,100000.0,200000.0,"ZERO","ZERO",100000.0,300000.0,100000.0,600000.0,"ZERO",1000000.0,"ZERO","ZERO",100000.0,100000.0,600000.0,200000.0,"ZERO",100000.0,300000.0,100000.0,30.0,"ZERO","ZERO","ZERO",100000.0,"ZERO","ZERO","ZERO","ZERO",300000.0,6700000.0,"ZERO","ZERO","ZERO","ZERO",100000.0,100000.0,100000.0,200000.0,"ZERO","ZERO",100000.0,800000.0,700000.0,300000.0,"ZERO","ZERO",100000.0,100000.0,100000.0,"ZERO","ZERO",400000.0,100000.0,2960.0,"ZERO","ZERO",400000.0,100000.0,100000.0,"ZERO","ZERO","ZERO","ZERO",100000.0,700000.0,200000.0,100000.0,"ZERO",300000.0,200000.0,100000.0,"ZERO","ZERO",100000.0,"ZERO","ZERO",100000.0,"ZERO",200000.0,"ZERO","ZERO",1000.0,100000.0,300000.0,300000.0,"ZERO","ZERO",200000.0,100000.0,1200000.0,"ZERO",10.0,"ZERO",100000.0,"ZERO",100000.0,"ZERO",100000.0,"ZERO",200000.0,"ZERO","ZERO","ZERO",100000.0,100000.0,2 ...

# %% [markdown]
# ## Fazer agora relacionado ao Brasil

# %%
cat_India = df2[(df2['country'] == 'India')]
print(cat_India)
# Out:
#                      youtuber country  uploads isantigoourecente  \
# 0                    T-Series   India    20082            Antigo
# 4                   SET India   India   116536            Antigo
# 10          Zee Music Company   India     8548            Antigo
# 15                   Sony SAB   India    71270            Antigo
# 21                     Zee TV   India   129204            Antigo
# ..                        ...     ...      ...               ...
# 980                  Zee Kids   India     1212            Antigo
# 981          Pari's Lifestyle   India      459           Recente
# 984      bharatzkitchen HINDI   India      729           Recente
# 991  Free Fire India Official   India     1500           Recente
# 994              Make Joke Of   India       62           Recente
#
#     subscribers_for_last_30_days          category
# 0                      2000000.0             Music
# 4                      1000000.0             Shows
# 10                     1100000.0             Music
# 15                     1100000.0             Shows
# 21                      900000.0     Entertainment
# ..                           ...               ...
# 980                     100000.0  Film & Animation
# 981                         ZERO    People & Blogs
# 984                     100000.0     Howto & Style
# 991                     300000.0    People & Blogs
# 994                     100000.0            Comedy
#
# [168 rows x 6 columns]

# %%
#Histograma
sns.countplot(cat_India, y='category')
# Out:
# <Axes: xlabel='count', ylabel='category'>

# %%
catg_India = cat_India.groupby('category')['youtuber'].count()

# %%
#depois fazer a soma das categorias com o numero de visualizações para ver qual a cateogria mais assistida, somando as duas com algum comando
plt.hist(catg_India, bins=20, edgecolor='black')

#adicionar titulos
plt.xlabel('category')

plt.title('Histograma das categorias USA')

plt.show()

# %%
import plotly.express as px

# %%
fig = px.scatter(cat_US, x='uploads', y= 'subscribers_for_last_30_days')

#botando o tutulo e os eixos
fig.update_layout(title = 'Gráfico de relação entre uploads e taxa de inscritos por canal')
fig.update_yaxes(title = 'Incritos no último mês')

#mostrar
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="20c8ce01-feba-489e-90b9-f5f0cb96a9c1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("20c8ce01-feba-489e-90b9-f5f0cb96a9c1")) {                    Plotly.newPlot(                        "20c8ce01-feba-489e-90b9-f5f0cb96a9c1",                        [{"hovertemplate":"uploads=%{x}\u003cbr\u003esubscribers_for_last_30_days=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"h","showlegend":false,"x":[1,741,966,1111,574,70127,3,2865,389,39113,156,436,216,147,847,65,3444,128,1218,618,2423,133,200933,11,15672,505,515,743,99,171,744,5490,2453,617,3366,188,2122,2068,166,116,1321,204,8976,92,578,2725,532,223,2,1349,4903,1513,5809,15,27,682,642,5438,554,241,6471,6873,865,775,1619,240,749,42,287,78,8775,2025,118,1894,104,175,120,658,36,252,590,4009,505,257,511,2425,443,1732,769,719,552,3657,1,172,4445,3781,0,985,180,171,2321,526,3315,1724,999,157,515,301,946,816,257,10162,228,51,733,78,1608,4728,403,420,498,982,9850,6,619,5062,47926,296,1006,761,3774,241,1481,2384,5491,1,7737,4339,1527,760,9930,250,1,17,18661,214,674,570,6526,139,60,2072,217,457,111,197,142,1324,420,707,45,237,5692,536,982,185,314,830,1426,26,178,156215,4411,180,1567,142,97,1910,366,3900,2337,1693,920,13,413,421,438,735,1091,14662,54,490,80,352,989,258,593,189,510,671,4045,2035,433,796,10441,7090,4245,0,417,1647,1756,21,851,160405,210,1037,2618,1362,0,20292,5198,1803,419,86,127,1210,1481,195,233,2222,3867,85,317,698,4340,1996,80830,1244,4009,365,67,479,453,1717,605,19201,147,463,450,1248,0,516,186,576,1,1724,43,182,41117,183,503,1660,504,369,173,412,199,8335,321,462,477,1349,3727,319,96,8195,331,698,3166,2742,4613,6916,538,4279,6888,33,289,435,194,716,612,1598,39,137,681,168,534,119,142,812,600,1101,99,601,61,1076,322,398,690,0,205,1340,99],"xaxis":"x","y":["ZERO",8000000.0,1000000.0,"ZERO",600000.0,600000.0,"ZERO",600000.0,100000.0,100000.0,300000.0,100000.0,800000.0,100000.0,600000.0,200000.0,400000.0,100000.0,1000000.0,"ZERO",100000.0,100000.0,100000.0,100.0,"ZERO",100000.0,200000.0,700000.0,200000.0,"ZERO",300000.0,100000.0,200000.0,300000.0,200000.0,200000.0,200000.0,300000.0,200000.0,200000.0,400000.0,"ZERO",100000.0,100000.0,200000.0,"ZERO",300000.0,"ZERO","ZERO","ZERO","ZERO",1000000.0,"ZERO",200000.0,"ZERO",100000.0,400000.0,200000.0,300000.0,1200000.0,200000.0,"ZERO",1300000.0,200000.0,400000.0,"ZERO",100000.0,100000.0,100000.0,100000.0,600000.0,300000.0,"ZERO",400000.0,100000.0,100000.0,200000.0,400000.0,100000.0,"ZERO",200000.0,200000.0,100000.0,"ZERO",300000.0,100000.0,100000.0,"ZERO",1100000.0,"ZERO",400000.0,100000.0,100000.0,100000.0,100000.0,700000.0,1.0,300000.0,100000.0,"ZERO",1300000.0,100000.0,200000.0,100000.0,200000.0,100000.0,200000.0,500000.0,400000.0,1900000.0,600000.0,100000.0,"ZERO",200000.0,200000.0,100000.0,200000.0,"ZERO","ZERO",100000.0,300000.0,100000.0,600000.0,"ZERO",1000000.0,"ZERO","ZERO",100000.0,100000.0,600000.0,200000.0,"ZERO",100000.0,300000.0,100000.0,30.0,"ZERO","ZERO","ZERO",100000.0,"ZERO","ZERO","ZERO","ZERO",300000.0,6700000.0,"ZERO","ZERO","ZERO","ZERO",100000.0,100000.0,100000.0,200000.0,"ZERO","ZERO",100000.0,800000.0,700000.0,300000.0,"ZERO","ZERO",100000.0,100000.0,100000.0,"ZERO","ZERO",400000.0,100000.0,2960.0,"ZERO","ZERO",400000.0,100000.0,100000.0,"ZERO","ZERO","ZERO","ZERO",100000.0,700000.0,200000.0,100000.0,"ZERO",300000.0,200000.0,100000.0,"ZERO","ZERO",100000.0,"ZERO","ZERO",100000.0,"ZERO",200000.0,"ZERO","ZERO",1000.0,100000.0,300000.0,300000.0,"ZERO","ZERO",200000.0,100000.0,1200000.0,"ZERO",10.0,"ZERO",100000.0,"ZERO",100000.0,"ZERO",100000.0,"ZERO",200000.0,"ZERO","ZERO","ZERO",100000.0,100000.0,2 ...

# %% [markdown]
# Agora

# %%
cat_UK = df2[(df2['country'] == 'India')]
print(cat_UK)
# Out:
#                      youtuber country  uploads isantigoourecente  \
# 0                    T-Series   India    20082            Antigo
# 4                   SET India   India   116536            Antigo
# 10          Zee Music Company   India     8548            Antigo
# 15                   Sony SAB   India    71270            Antigo
# 21                     Zee TV   India   129204            Antigo
# ..                        ...     ...      ...               ...
# 980                  Zee Kids   India     1212            Antigo
# 981          Pari's Lifestyle   India      459           Recente
# 984      bharatzkitchen HINDI   India      729           Recente
# 991  Free Fire India Official   India     1500           Recente
# 994              Make Joke Of   India       62           Recente
#
#     subscribers_for_last_30_days          category
# 0                      2000000.0             Music
# 4                      1000000.0             Shows
# 10                     1100000.0             Music
# 15                     1100000.0             Shows
# 21                      900000.0     Entertainment
# ..                           ...               ...
# 980                     100000.0  Film & Animation
# 981                         ZERO    People & Blogs
# 984                     100000.0     Howto & Style
# 991                     300000.0    People & Blogs
# 994                     100000.0            Comedy
#
# [168 rows x 6 columns]

# %%
sns.countplot(cat_UK, y='category')
# Out:
# <Axes: xlabel='count', ylabel='category'>

# %%
catg_UK = cat_UK.groupby('category')['youtuber'].count()

# %%
#depois fazer a soma das categorias com o numero de visualizações para ver qual a cateogria mais assistida, somando as duas com algum comando
plt.hist(catg_UK, bins=20, edgecolor='black')

#adicionar titulos
plt.xlabel('category')

plt.title('Histograma das categorias USA')

plt.show()

# %%
cat_Mexico = df2[(df2['country'] == 'Mexico')]
print(cat_Mexico)
# Out:
#                                               youtuber country  uploads  \
# 71                                     Kimberly Loaiza  Mexico      291
# 73                                    Luisito Comunica  Mexico        0
# 142                                             GENIAL  Mexico     6734
# 224                                      LosPolinesios  Mexico      982
# 243                                               Yuya  Mexico      672
# 254                                MrBeast en Espaï¿½ï  Mexico       67
# 277                               Juan De Dios Pantoja  Mexico      226
# 301  BabyBus - Canciones Infantiles & Videos para N...  Mexico     1251
# 324                              Disney Latinoamï¿½ï¿½  Mexico      116
# 337                                          Tlnovelas  Mexico      158
# 421                                            JukiLop  Mexico       85
# 434                              SUPER SLICK SLIME SAM  Mexico      903
# 441       Little Angel Espaï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½  Mexico      719
# 506                                      MissaSinfonia  Mexico      233
# 552                                      Tu COSMOPOLIS  Mexico     8741
# 554                                      Werever2morro  Mexico        0
# 600                               La Rosa de Guadalupe  Mexico        0
# 603                                             Antrax  Mexico      687
# 605                              Totoy kids - Espaï¿½ï  Mexico      344
# 623                                           Caeli YT  Mexico      483
# 628                                    Blippi Espaï¿½ï  Mexico      598
# 681                                           XpressTV  Mexico      724
# 733                                     Mis Pastelitos  Mexico      603
# 775                                     E-MasterSensei  Mexico     1300
# 794                                      TV Ana Emilia  Mexico      651
# 797                                  Gallina Pintadita  Mexico       62
# 817                                    123 GO! Spanish  Mexico      520
# 908                                        Susy Mouriz  Mexico     1299
# 932                                   Franco Escamilla  Mexico     2483
# 953                                             Yair17  Mexico     1109
# 956                                      Mï¿½ï¿½ï¿½ï¿½  Mexico      766
# 961                                  elcarteldesantatv  Mexico      377
# 974                                           Gibby :)  Mexico      226
#
#     isantigoourecente subscribers_for_last_30_days          category
# 71            Recente                     400000.0    People & Blogs
# 73             Antigo                         ZERO            Comedy
# 142           Recente                         ZERO     Howto & Style
# 224            Antigo                         ZERO    People & Blogs
# 243            Antigo                         ZERO     Howto & Style
# 254           Recente                     100000.0     Entertainment
# 277            Antigo                     200000.0     Entertainment
# 301           Recente                     200000.0         Education
# 324            Antigo                         ZERO     Entertainment
# 337            Antigo                         ZERO   News & Politics
# 421           Recente                     100000.0    People & Blogs
# 434           Recente                     200000.0     Howto & Style
# 441           Recente                         ZERO         Education
# 506            Antigo                     100000.0            Comedy
# 552            Antigo                         ZERO    People & Blogs
# 554            Antigo                         ZERO     Entertainment
# 600            Antigo                         ZERO     Entertainment
# 603           Recente                         ZERO            Gaming
# 605           Recente                     200000.0  Film & Animation
# 623            Antigo                         ZERO     Entertainment
# 628           Recente                     100000.0    People & Blogs
# 681            Antigo                     100000.0     Entertainment
# 733            Antigo                     100000.0     Howto & Style
# 775           Recente                     200000.0            Gaming
# 794            Antigo                     100000.0    People & Blogs
# 797            Antigo                         ZERO             Music
# 817           Recente                     100000.0    People & Blogs
# 908           Recente                     600000.0     Entertainment
# 932            Antigo                     100000.0            Comedy
# 953            Antigo                         ZERO            Gaming
# 956           Recente                         ZERO   Travel & Events
# 961            Antigo                     100000.0             Music
# 974            Antigo                         ZERO    People & Blogs

# %%
sns.countplot(cat_Mexico, y='category')
# Out:
# <Axes: xlabel='count', ylabel='category'>

# %%
cat_Indonesia = df2[(df2['country'] == 'Indonesia')]
print(cat_Indonesia)
# Out:
#                               youtuber    country  uploads isantigoourecente  \
# 117                      Jess No Limit  Indonesia     2284           Recente
# 129                     Ricis Official  Indonesia     2736           Recente
# 159                                 AH  Indonesia     2197            Antigo
# 221                           Indosiar  Indonesia    65286            Antigo
# 230                 Rans Entertainment  Indonesia     3716           Recente
# 240                    TRANS7 OFFICIAL  Indonesia    89179            Antigo
# 351                         Baim Paula  Indonesia     2325           Recente
# 369                    Deddy Corbuzier  Indonesia       15            Antigo
# 383  BabyBus - Cerita & Lagu Anak-anak  Indonesia      875           Recente
# 390                            MiawAug  Indonesia     3713            Antigo
# 459                       Willie Salim  Indonesia      679            Antigo
# 465        Naisa Alifia Yuriza (N.A.Y)  Indonesia      786           Recente
# 472                     GEN HALILINTAR  Indonesia     1037           Recente
# 499                         tanboy kun  Indonesia      739           Recente
# 530                  TRANS TV Official  Indonesia   148225            Antigo
# 546                    Like Nastya IDN  Indonesia      502           Recente
# 591                        Dyland PROS  Indonesia     2805           Recente
# 615                      Arif muhammad  Indonesia      542           Recente
# 645                  Kerajinan 5-Menit  Indonesia     4186           Recente
# 662                     Daftar Populer  Indonesia     3810           Recente
# 689                           KOMPASTV  Indonesia   269050            Antigo
# 694                     MNCTV OFFICIAL  Indonesia    66362            Antigo
# 787                     Yudist Ardhana  Indonesia     2854           Recente
# 838                      BUDI01 GAMING  Indonesia      319           Recente
# 879                             Vilmei  Indonesia     1324            Antigo
# 902                      Calon Sarjana  Indonesia       29           Recente
# 921                   The Shiny Peanut  Indonesia     2337           Recente
# 976                     SAAIHALILINTAR  Indonesia      409            Antigo
#
#     subscribers_for_last_30_days         category
# 117                    5500000.0    Entertainment
# 129                    1900000.0   People & Blogs
# 159                         ZERO    Entertainment
# 221                     600000.0            Music
# 230                     100000.0   People & Blogs
# 240                     100000.0    Entertainment
# 351                     100000.0   People & Blogs
# 369                          1.0    Entertainment
# 383                     100000.0        Education
# 390                     200000.0           Gaming
# 459                    1600000.0   People & Blogs
# 465                         ZERO   People & Blogs
# 472                         ZERO    Entertainment
# 499                     100000.0   People & Blogs
# 530                     100000.0    Entertainment
# 546                     100000.0    Entertainment
# 591                         ZERO    Entertainment
# 615                     100000.0   People & Blogs
# 645                         ZERO   People & Blogs
# 662                     100000.0        Education
# 689                     100000.0  News & Politics
# 694                     100000.0    Entertainment
# 787                     400000.0    Entertainment
# 838                         ZERO           Gaming
# 879                     800000.0              NaN
# 902                     300000.0    Entertainment
# 921                         ZERO        Education
# 976                         ZERO    Entertainment

# %%
sns.countplot(cat_Indonesia, y='category')
# Out:
# <Axes: xlabel='count', ylabel='category'>

# %%
cat_Espanha = df2[(df2['country'] == 'Spain')]
print(cat_Espanha)

sns.countplot(cat_Espanha, y='category')
# Out:
#                                           youtuber country  uploads  \
# 81                                       Mikecrack   Spain     1876
# 119                                     VEGETTA777   Spain     7606
# 177                                      AuronPlay   Spain      404
# 449                                            CKN   Spain       16
# 461                                    TheWillyrex   Spain     6943
# 482                                       TheGrefg   Spain     3566
# 528                                       Willyrex   Spain     7550
# 555                             IDEAS EN 5 MINUTOS   Spain      216
# 589                                           AdMe   Spain       10
# 646                                   FC Barcelona   Spain    10988
# 667                                     Makiman131   Spain     2997
# 697              iTownGamePlay *Terror&Diversiï¿½ï   Spain     8420
# 716                                Canal Nostalgia   Spain      554
# 726                                          Auron   Spain      961
# 796                                   Luli Pampï¿½   Spain      294
# 831                                         Acenix   Spain      368
# 913                                     gymvirtual   Spain     1572
# 924                              Duo Tiempo De Sol   Spain      323
# 933                                    Adexe & Nau   Spain      594
# 954                    Little Baby Bum en Espaï¿½ï   Spain     1459
# 977                                       Timba Vk   Spain     1024
# 979  DaniRep | +6 Vï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï   Spain    12419
#
#     isantigoourecente subscribers_for_last_30_days        category
# 81            Recente                     800000.0          Gaming
# 119            Antigo                         ZERO          Gaming
# 177            Antigo                         ZERO          Comedy
# 449            Antigo                          1.0   Entertainment
# 461            Antigo                         ZERO          Comedy
# 482            Antigo                         ZERO          Gaming
# 528            Antigo                         ZERO          Gaming
# 555           Recente                         ZERO   Howto & Style
# 589            Antigo                         ZERO   Entertainment
# 646            Antigo                     200000.0          Sports
# 667            Antigo                         ZERO          Gaming
# 697            Antigo                     100000.0   Entertainment
# 716            Antigo                        600.0   Entertainment
# 726            Antigo                         ZERO  People & Blogs
# 796            Antigo                     100000.0           Music
# 831            Antigo                     200000.0          Gaming
# 913            Antigo                     100000.0          Sports
# 924            Antigo                     100000.0           Music
# 933            Antigo                         ZERO           Music
# 954            Antigo                         ZERO       Education
# 977            Antigo                     100000.0          Gaming
# 979            Antigo                     100000.0          Gaming
# <Axes: xlabel='count', ylabel='category'>

# %%
cat_Thailandia = df2[(df2['country'] == 'Thailand')]
print(cat_Thailandia)

sns.countplot(cat_Thailandia, y='category')
# Out:
#                                             youtuber   country  uploads  \
# 61                                       Alan Walker  Thailand        8
# 82                                 WorkpointOfficial  Thailand    72580
# 93                                ýýýýýýýýýýýý one31  Thailand   117152
# 125                                      Ch3Thailand  Thailand    96214
# 290                              GMM GRAMMY OFFICIAL  Thailand    15462
# 453                             GRAMMY GOLD OFFICIAL  Thailand     6287
# 462            RsiamMusic : ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½  Thailand     3159
# 505                                         zbing z.  Thailand     3151
# 516  AMARINTV : ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½  Thailand   118448
# 566                                  Kaykai Salaider  Thailand      428
# 568                                            Ch7HD  Thailand    56203
# 571                             GMMTV OFFICIALï¿½ï¿½  Thailand    23952
# 586                                  Thairath Online  Thailand   244899
# 643                                        Genierock  Thailand     1725
# 698                         ýýýýýýýýýýýý8 : Thai Ch8  Thailand    27944
# 746                                    GMM25Thailand  Thailand    68606
# 791                                      Bie The Ska  Thailand     1540
# 855                                     My Mate Nate  Thailand     1195
#
#     isantigoourecente subscribers_for_last_30_days         category
# 61             Antigo                         ZERO            Music
# 82             Antigo                     200000.0    Entertainment
# 93             Antigo                     300000.0    Entertainment
# 125            Antigo                     100000.0    Entertainment
# 290            Antigo                         ZERO            Music
# 453            Antigo                     100000.0            Music
# 462            Antigo                     100000.0            Music
# 505            Antigo                         ZERO           Gaming
# 516            Antigo                     200000.0    Entertainment
# 566            Antigo                         ZERO           Comedy
# 568            Antigo                     100000.0    Entertainment
# 571            Antigo                     200000.0    Entertainment
# 586            Antigo                     100000.0  News & Politics
# 643            Antigo                     100000.0            Music
# 698            Antigo                     100000.0    Entertainment
# 746            Antigo                     100000.0    Entertainment
# 791            Antigo                     100000.0    Entertainment
# 855            Antigo                         ZERO           Comedy
# <Axes: xlabel='count', ylabel='category'>

# %%
cat_SK = df2[(df2['country'] == 'South Korea')]
print(cat_SK)

sns.countplot(cat_SK, y='category')
# Out:
#                                               youtuber      country  uploads  \
# 13                                           BLACKPINK  South Korea      543
# 17                                           BANGTANTV  South Korea     2281
# 20                                         HYBE LABELS  South Korea     1337
# 195                                  JYP Entertainment  South Korea     1753
# 250                               1theK (ï¿½ï¿½ï¿½ï¿½ï  South Korea    18950
# 372                                         Mnet K-POP  South Korea    33229
# 438                                       KBS WORLD TV  South Korea    64496
# 475                                        officialpsy  South Korea      131
# 495                                   ýýýýýýýýý KIMPRO  South Korea     1646
# 496                                   Jane ASMR ï¿½ï¿½  South Korea     1888
# 510                                          JFlaMusic  South Korea      326
# 671                                            BIGBANG  South Korea      776
# 743  Boram Tube ToysReview [ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿  South Korea      618
# 752                              ýýýýýýýýýýýýýýýýýýýýý  South Korea      364
# 905                                               GH'S  South Korea      510
# 914                                  BIBOï¿½ï¿½ï¿½ï¿½ï  South Korea      193
# 945                                     ýýýýýýýýýSULGI  South Korea      683
#
#     isantigoourecente subscribers_for_last_30_days        category
# 13            Recente                     700000.0  People & Blogs
# 17             Antigo                     400000.0           Music
# 20             Antigo                     900000.0           Music
# 195            Antigo                     200000.0           Music
# 250            Antigo                         ZERO           Music
# 372            Antigo                     100000.0   Entertainment
# 438            Antigo                         ZERO   Entertainment
# 475            Antigo                         ZERO           Music
# 495           Recente                    3200000.0             NaN
# 496            Antigo                         ZERO             NaN
# 510            Antigo                         ZERO           Music
# 671            Antigo                         ZERO           Music
# 743           Recente                         ZERO  People & Blogs
# 752           Recente                     300000.0   Entertainment
# 905           Recente                    1000000.0          Gaming
# 914           Recente                         ZERO   Entertainment
# 945            Antigo                     300000.0  People & Blogs
# <Axes: xlabel='count', ylabel='category'>

# %%
cat_Russia = df2[(df2['country'] == 'Russia')]
print(cat_Russia)

sns.countplot(cat_Russia, y='category')
# Out:
#                        youtuber country  uploads isantigoourecente  \
# 8                   Like Nastya  Russia      493           Recente
# 46                   Get Movies  Russia     3322            Antigo
# 64   ýýýýýýýý ýý ýýýýýýýýýýýýýý  Russia     1478            Antigo
# 367            tuzelity SHUFFLE  Russia      889           Recente
# 439                       HiMan  Russia      375            Antigo
# 456                      Marmok  Russia      374            Antigo
# 458            Like Nastya Vlog  Russia      493           Recente
# 529                TheBrianMaps  Russia      498            Antigo
# 606                  ýýýýýýýýýý  Russia        0           Recente
# 649                 ILYA BORZOV  Russia     2175           Recente
# 670                   EdisonPts  Russia     3733            Antigo
# 674                 Chapitosiki  Russia     2717           Recente
# 700                      ýýýýýý  Russia        1            Antigo
# 795                ýýýýýýýýýýýý  Russia     2210            Antigo
# 866          ýýýýýýýýýýýýýýýýýý  Russia      608           Recente
# 875      BIBO ï¿½ï¿½ï¿½ï¿½ï¿½ï¿  Russia      192           Recente
#
#     subscribers_for_last_30_days          category
# 8                       100000.0    People & Blogs
# 46                      700000.0     Entertainment
# 64                      300000.0  Film & Animation
# 367                    1600000.0    People & Blogs
# 439                         ZERO    People & Blogs
# 456                     100000.0            Gaming
# 458                     100000.0    People & Blogs
# 529                     100000.0            Comedy
# 606                         10.0    People & Blogs
# 649                     800000.0    People & Blogs
# 670                     100000.0            Gaming
# 674                     700000.0     Entertainment
# 700                         ZERO    People & Blogs
# 795                     200000.0            Gaming
# 866                     100000.0    People & Blogs
# 875                     200000.0     Entertainment
# <Axes: xlabel='count', ylabel='category'>

# %%
cat_Canada = df2[(df2['country'] == 'Canada')]
print(cat_Canada)

sns.countplot(cat_Canada, y='category')
# Out:
#                             youtuber country  uploads isantigoourecente  \
# 19                     Justin Bieber  Canada      249            Antigo
# 80   Super Simple Songs - Kids Songs  Canada      744            Antigo
# 134                       The Weeknd  Canada      169            Antigo
# 170                     Shawn Mendes  Canada      133            Antigo
# 222                     VanossGaming  Canada     1762            Antigo
# 239                    WatchMojo.com  Canada    24837            Antigo
# 273                         FaZe Rug  Canada        0            Antigo
# 403                       Pentatonix  Canada        1            Antigo
# 625                  Linus Tech Tips  Canada     6542            Antigo
# 751                      Lilly Singh  Canada     1064            Antigo
# 814             Hacksmith Industries  Canada      887            Antigo
# 839                    Typical Gamer  Canada     4312            Antigo
# 873                         AzzyLand  Canada     1749           Recente
# 926                   MrSuicideSheep  Canada     3483            Antigo
# 978         Heidi and Zidane HZHtube  Canada      813           Recente
#
#     subscribers_for_last_30_days              category
# 19                      100000.0                 Music
# 80                      400000.0             Education
# 134                     200000.0                 Music
# 170                         ZERO                 Music
# 222                         ZERO                Gaming
# 239                         ZERO                 Music
# 273                          1.0                Gaming
# 403                         ZERO                 Music
# 625                     100000.0  Science & Technology
# 751                         ZERO                Comedy
# 814                     100000.0  Science & Technology
# 839                         ZERO                Gaming
# 873                     100000.0                Gaming
# 926                         ZERO         Entertainment
# 978                         ZERO         Entertainment
# <Axes: xlabel='count', ylabel='category'>

# %%
cat_Arg = df2[(df2['country'] == 'Argentina')]
print(cat_Arg)

sns.countplot(cat_Arg, y='category')
# Out:
#                   youtuber    country  uploads isantigoourecente  \
# 31       El Reino Infantil  Argentina     1510            Antigo
# 105    La Granja de Zenï¿½  Argentina      654            Antigo
# 153              TheDonato  Argentina     3027           Recente
# 174                 Maluma  Argentina       14           Recente
# 257             Alejo Igoa  Argentina      802            Antigo
# 296           DrossRotzank  Argentina     1598            Antigo
# 314           Paulo Londra  Argentina       58           Recente
# 370               Bizarrap  Argentina       83           Recente
# 486            RobleisIUTU  Argentina     1344            Antigo
# 504    El Payaso Plim Plim  Argentina     1316            Antigo
# 527       El Reino a Jugar  Argentina     1007           Recente
# 609                   Lyna  Argentina     4906            Antigo
# 672  Rubï¿½ï¿½ï¿½ï¿½ï¿½ï¿½  Argentina      921           Recente
#
#     subscribers_for_last_30_days          category
# 31                      600000.0             Music
# 105                     400000.0             Music
# 153                    1900000.0     Entertainment
# 174                         ZERO             Music
# 257                     600000.0            Comedy
# 296                     100000.0     Entertainment
# 314                         ZERO             Music
# 370                     200000.0            Comedy
# 486                     100000.0     Entertainment
# 504                     600000.0  Film & Animation
# 527                     100000.0         Education
# 609                     200000.0            Gaming
# 672                     700000.0            Comedy
# <Axes: xlabel='count', ylabel='category'>

# %%
cat_Phil = df2[(df2['country'] == 'Philippines')]
print(cat_Phil)

sns.countplot(cat_Phil, y='category')
# Out:
#                   youtuber      country  uploads isantigoourecente  \
# 60   ABS-CBN Entertainment  Philippines   193890            Antigo
# 141           GMA  Network  Philippines    93311            Antigo
# 208  Raffy Tulfo in Action  Philippines    10022           Recente
# 349    GMA Public  Affairs  Philippines    31989            Antigo
# 553            Ivana Alawi  Philippines      180           Recente
# 653         Niana Guerrero  Philippines      443            Antigo
# 664              Ranz Kyle  Philippines      533            Antigo
# 673           ABS-CBN News  Philippines   209520            Antigo
# 770             Wish 107.5  Philippines     1823            Antigo
# 832          Zeinab Harake  Philippines      273           Recente
# 857    GMA Integrated News  Philippines   296272            Antigo
# 887  Alex Gonzaga Official  Philippines      287           Recente
#
#     subscribers_for_last_30_days         category
# 60                      300000.0   People & Blogs
# 141                     500000.0    Entertainment
# 208                     300000.0  News & Politics
# 349                     200000.0    Entertainment
# 553                     100000.0              NaN
# 653                         ZERO    Entertainment
# 664                         ZERO   People & Blogs
# 673                     100000.0  News & Politics
# 770                         ZERO            Music
# 832                     100000.0              NaN
# 857                     100000.0  News & Politics
# 887                         ZERO   People & Blogs
# <Axes: xlabel='count', ylabel='category'>

# %%
cat_Colombia = df2[(df2['country'] == 'Colombia')]
print(cat_Colombia)

sns.countplot(cat_Colombia, y='category')
# Out:
#           youtuber   country  uploads isantigoourecente  \
# 63         Shakira  Colombia      326            Antigo
# 116       J Balvin  Colombia      141            Antigo
# 136        KAROL G  Colombia      134            Antigo
# 192    toycantando  Colombia      619            Antigo
# 206      enchufetv  Colombia      975            Antigo
# 241       Anuel AA  Colombia      147           Recente
# 384  Ami Rodriguez  Colombia      460            Antigo
# 612         Camilo  Colombia      132            Antigo
# 850       Codiscos  Colombia     7356            Antigo
# 882    jbalvinVEVO  Colombia      237            Antigo
# 942     Go Ami Go!  Colombia      252           Recente
#
#     subscribers_for_last_30_days        category
# 63                      500000.0  People & Blogs
# 116                     100000.0           Music
# 136                     300000.0           Music
# 192                     200000.0           Music
# 206                         ZERO          Comedy
# 241                     300000.0           Music
# 384                    1600000.0   Entertainment
# 612                     100000.0           Music
# 850                     100000.0           Music
# 882                         ZERO           Music
# 942                    1500000.0  People & Blogs
# <Axes: xlabel='count', ylabel='category'>

# %%
cat_Australia = df2[(df2['country'] == 'Australia')]
print(cat_Australia)

sns.countplot(cat_Australia, y='category')
# Out:
#                        youtuber    country  uploads isantigoourecente  \
# 191  Bounce Patrol - Kids Songs  Australia      292            Antigo
# 247                  Chloe Ting  Australia      412            Antigo
# 373                   LazarBeam  Australia     1323           Recente
# 478              How Ridiculous  Australia      650            Antigo
# 508          The Game Theorists  Australia        0           Recente
# 522                  HowToBasic  Australia      582            Antigo
# 526                 Jason Vlogs  Australia       83            Antigo
# 706                     Lachlan  Australia     3834            Antigo
# 785                   Trap City  Australia        3           Recente
#
#     subscribers_for_last_30_days       category
# 191                         ZERO          Music
# 247                         ZERO  Howto & Style
# 373                         ZERO         Gaming
# 478                     600000.0         Sports
# 508                         ZERO         Gaming
# 522                         ZERO  Howto & Style
# 526                         ZERO      Education
# 706                         ZERO         Gaming
# 785                          1.0          Music
# <Axes: xlabel='count', ylabel='category'>

# %%
cat_Arabia_Saudita = df2[(df2['country'] == 'Saudi Arabia')]
print(cat_Arabia_Saudita)

sns.countplot(cat_Arabia_Saudita, y='category')
# Out:
#                                               youtuber       country  uploads  \
# 85                                                shfa  Saudi Arabia      982
# 217                              1MILLION Dance Studio  Saudi Arabia        0
# 308                                           mmoshaya  Saudi Arabia     1189
# 454  ýýýýýýýý ýýýýýýýýýý ýýýýýýýýýý | Arab Games Ne...  Saudi Arabia     6289
# 630                                    Katakit Baby TV  Saudi Arabia      220
# 632                               ýýýýýýýý ýý ýýýýýýýý  Saudi Arabia     1021
# 714                            ýýýýýýýýýý ýýýýýýýýýýýý  Saudi Arabia     1385
# 756   ýýýýýýýýýýýý ýýýýýýýýýýýý I ýýýýýý ýý ýýýýýýýýýý  Saudi Arabia      381
# 872                                         BanderitaX  Saudi Arabia     1640
#
#     isantigoourecente subscribers_for_last_30_days        category
# 85            Recente                       2000.0  People & Blogs
# 217           Recente                         ZERO   Entertainment
# 308            Antigo                     100000.0  People & Blogs
# 454            Antigo                     500000.0          Gaming
# 630            Antigo                     200000.0           Music
# 632           Recente                     300000.0           Shows
# 714           Recente                         ZERO   Entertainment
# 756           Recente                         ZERO   Entertainment
# 872            Antigo                     200000.0          Gaming
# <Axes: xlabel='count', ylabel='category'>

# %%
cat_Ukrania = df2[(df2['country'] == 'Ukraine')]
print(cat_Ukrania)

sns.countplot(cat_Ukrania, y='category')
# Out:
#                          youtuber  country  uploads isantigoourecente  \
# 379                    SlivkiShow  Ukraine      462            Antigo
# 447        ýýýýýýýýýýýýýýýýýýýýýý  Ukraine      530            Antigo
# 502                       News 24  Ukraine   211620            Antigo
# 707             ýýýýýýýý ýýýýýýýý  Ukraine     2387           Recente
# 772                    SIS vs BRO  Ukraine       60           Recente
# 843                    Lady Diana  Ukraine     1403           Recente
# 868                       VexTrex  Ukraine     2411            Antigo
# 920  ýýýýýýýý ýýýý ýýýýýýýýýýýýýý  Ukraine     1255            Antigo
#
#     subscribers_for_last_30_days         category
# 379                         ZERO    Entertainment
# 447                     100000.0    Entertainment
# 502                     230000.0  News & Politics
# 707                         ZERO    Howto & Style
# 772                         10.0    Entertainment
# 843                     100000.0    Entertainment
# 868                         ZERO    Entertainment
# 920                     200000.0            Shows
# <Axes: xlabel='count', ylabel='category'>

# %%
cat_UAE = df2[(df2['country'] == 'United Arab Emirates')]
print(cat_UAE)

sns.countplot(cat_UAE, y='category')
# Out:
#                        youtuber               country  uploads  \
# 76               shfa2 - ï¿½ï¿½  United Arab Emirates     1596
# 255             shfa show India  United Arab Emirates      469
# 332  ZAMZAM ELECTRONICS TRADING  United Arab Emirates    15126
# 385                  Noor Stars  United Arab Emirates      693
# 639                      FFUNTV  United Arab Emirates      379
# 786            Supercar Blondie  United Arab Emirates      855
# 917    AlArabiya ï¿½ï¿½ï¿½ï¿½ï¿  United Arab Emirates   169304
#
#     isantigoourecente subscribers_for_last_30_days          category
# 76            Recente                     300000.0    People & Blogs
# 255           Recente                     200000.0               NaN
# 332           Recente                    3400000.0               NaN
# 385            Antigo                     100000.0            Comedy
# 639           Recente                     200000.0            Gaming
# 786            Antigo                     500000.0  Autos & Vehicles
# 917            Antigo                     100000.0    People & Blogs
# <Axes: xlabel='count', ylabel='category'>

# %%
cat_Alemanha = df2[(df2['country'] == 'Germany')]
print(cat_Alemanha)

sns.countplot(cat_Alemanha, y='category')
# Out:
#                          youtuber  country  uploads isantigoourecente  \
# 294                  Tsuriki Show  Germany     2905           Recente
# 340                          YOLO  Germany        0            Antigo
# 363  Kurzgesagt ï¿½ï¿½ï¿½ï¿½ï¿½ï¿  Germany      193            Antigo
# 406                    HaerteTest  Germany     1411            Antigo
# 559                  Younes Zarou  Germany     2200           Recente
# 711            Beast Philanthropy  Germany       34           Recente
#
#     subscribers_for_last_30_days              category
# 294                     800000.0         Entertainment
# 340                          5.0                Comedy
# 363                     100000.0             Education
# 406                         ZERO  Science & Technology
# 559                     900000.0         Entertainment
# 711                       3580.0        People & Blogs
# <Axes: xlabel='count', ylabel='category'>

# %%
cat_Pakistan = df2[(df2['country'] == 'Pakistan')]
print(cat_Pakistan)

sns.countplot(cat_Pakistan, y='category')
# Out:
#             youtuber   country  uploads isantigoourecente  \
# 56       HAR PAL GEO  Pakistan   100755            Antigo
# 65    ARY Digital HD  Pakistan   109871           Recente
# 185           HUM TV  Pakistan   106983            Antigo
# 818         Geo News  Pakistan   190093            Antigo
# 907   Wolfoo Channel  Pakistan       22           Recente
# 969  Quantum Tech HD  Pakistan      223           Recente
#
#     subscribers_for_last_30_days              category
# 56                     1300000.0         Entertainment
# 65                      900000.0         Entertainment
# 185                     700000.0         Entertainment
# 818                     100000.0       News & Politics
# 907                          8.0                   NaN
# 969                         32.0  Science & Technology
# <Axes: xlabel='count', ylabel='category'>

# %%
cat_France = df2[(df2['country'] == 'France')]
print(cat_France)

sns.countplot(cat_France, y='category')
# Out:
#          youtuber country  uploads isantigoourecente  \
# 315  Smile Family  France       34           Recente
# 473      SQUEEZIE  France     1521            Antigo
# 597      FitDance  France       41            Antigo
# 757       Cyprien  France      222            Antigo
# 903     Lofi Girl  France      409           Recente
#
#     subscribers_for_last_30_days        category
# 315                         10.0  People & Blogs
# 473                     100000.0          Gaming
# 597                          4.0           Music
# 757                         ZERO          Comedy
# 903                     100000.0           Music
# <Axes: xlabel='count', ylabel='category'>

# %%
cat_Japao = df2[(df2['country'] == 'Japan')]
print(cat_Japao)
# Out:
#                  youtuber country  uploads isantigoourecente  \
# 7               PewDiePie   Japan     4716            Antigo
# 215    Junya.ï¿½ï¿½ï¿½ï¿½   Japan     5985           Recente
# 320     Sagawa /ï¿½ï¿½ï¿½   Japan     6274           Recente
# 690  ISSEI / ï¿½ï¿½ï¿½ï¿½   Japan     1788            Antigo
# 702            Bayashi TV   Japan       93            Antigo
#
#     subscribers_for_last_30_days       category
# 7                           ZERO         Gaming
# 215                    1100000.0  Entertainment
# 320                     800000.0  Entertainment
# 690                     900000.0         Comedy
# 702                          9.0  Entertainment

# %%
#Agora do Japão
sns.countplot(cat_Japao, y='category')
# Out:
# <Axes: xlabel='count', ylabel='category'>

# %%
catg_Japan = cat_Japao.groupby('category')['youtuber'].count()

plt.hist(catg_Japan, bins=20, edgecolor='black')

#adicionar titulos
plt.xlabel('category')

plt.title('Histograma das categorias USA')

plt.show()

# %%
df[ (df['country'] == 'Japan')]
#pewdiepie é da Suécia mas como o canal tem relação com o Japão ele está listado como de lá
# Out:
#      rank              youtuber  subscribers   video views       category  \
# 7       8             PewDiePie    111000000  2.905804e+10         Gaming
# 215   216    Junya.ï¿½ï¿½ï¿½ï¿½     26200000  1.609753e+10  Entertainment
# 320   321     Sagawa /ï¿½ï¿½ï¿½     22000000  1.834797e+10  Entertainment
# 690   691  ISSEI / ï¿½ï¿½ï¿½ï¿½     15000000  1.356285e+10         Comedy
# 702   703            Bayashi TV     14900000  8.615619e+09  Entertainment
#
#                            title  uploads country abbreviation   channel_type  \
# 7                      PewDiePie     4716   Japan           JP  Entertainment
# 215           Junya.ï¿½ï¿½ï¿½ï¿½     5985   Japan           JP  Entertainment
# 320            Sagawa /ï¿½ï¿½ï¿½     6274   Japan           JP  Entertainment
# 690         ISSEI / ï¿½ï¿½ï¿½ï¿½     1788   Japan           JP         Comedy
# 702  ýýýýýýýýýýýýýýýýýýBAYASHITV       93   Japan           JP          Autos
#
#      ...  created_year  created_month  created_date  \
# 7    ...        2010.0            Apr          29.0
# 215  ...        2020.0            Sep          14.0
# 320  ...        2021.0            Feb          13.0
# 690  ...        2014.0            Jul          23.0
# 702  ...        2012.0            Nov          19.0
#
#      gross tertiary education enrollment (%)   population  unemployment rate  \
# 7                                       63.2  126226568.0               2.29
# 215                                     63.2  126226568.0               2.29
# 320                                     63.2  126226568.0               2.29
# 690                                     63.2  126226568.0               2.29
# 702                                     63.2  126226568.0               2.29
#
#      urban_population   latitude   longitude  isantigoourecente
# 7         115782416.0  36.204824  138.252924             Antigo
# 215       115782416.0  36.204824  138.252924            Recente
# 320       115782416.0  36.204824  138.252924            Recente
# 690       115782416.0  36.204824  138.252924             Antigo
# 702       115782416.0  36.204824  138.252924             Antigo
#
# [5 rows x 29 columns]

# %%
cat_Tuqruia = df2[(df2['country'] == 'Turkey')]
print(cat_Tuqruia)

sns.countplot(cat_Tuqruia, y='category')
# Out:
#           youtuber country  uploads isantigoourecente  \
# 132  BETER Bï¿½ï¿½  Turkey     2738            Antigo
# 259    netd mï¿½ï¿  Turkey    23491            Antigo
# 416     tabii Urdu  Turkey     1306           Recente
# 657   Oyuncak Avï¿  Turkey      654            Antigo
#
#     subscribers_for_last_30_days       category
# 132                    2100000.0            NaN
# 259                     200000.0          Music
# 416                     100000.0  Entertainment
# 657                         ZERO  Entertainment
# <Axes: xlabel='count', ylabel='category'>

# %%
cat_Suiça = df2[(df2['country'] == 'Sweden')]
print(cat_Indonesia)

sns.countplot(cat_Suiça, y='category')
# Out:
#                               youtuber    country  uploads isantigoourecente  \
# 117                      Jess No Limit  Indonesia     2284           Recente
# 129                     Ricis Official  Indonesia     2736           Recente
# 159                                 AH  Indonesia     2197            Antigo
# 221                           Indosiar  Indonesia    65286            Antigo
# 230                 Rans Entertainment  Indonesia     3716           Recente
# 240                    TRANS7 OFFICIAL  Indonesia    89179            Antigo
# 351                         Baim Paula  Indonesia     2325           Recente
# 369                    Deddy Corbuzier  Indonesia       15            Antigo
# 383  BabyBus - Cerita & Lagu Anak-anak  Indonesia      875           Recente
# 390                            MiawAug  Indonesia     3713            Antigo
# 459                       Willie Salim  Indonesia      679            Antigo
# 465        Naisa Alifia Yuriza (N.A.Y)  Indonesia      786           Recente
# 472                     GEN HALILINTAR  Indonesia     1037           Recente
# 499                         tanboy kun  Indonesia      739           Recente
# 530                  TRANS TV Official  Indonesia   148225            Antigo
# 546                    Like Nastya IDN  Indonesia      502           Recente
# 591                        Dyland PROS  Indonesia     2805           Recente
# 615                      Arif muhammad  Indonesia      542           Recente
# 645                  Kerajinan 5-Menit  Indonesia     4186           Recente
# 662                     Daftar Populer  Indonesia     3810           Recente
# 689                           KOMPASTV  Indonesia   269050            Antigo
# 694                     MNCTV OFFICIAL  Indonesia    66362            Antigo
# 787                     Yudist Ardhana  Indonesia     2854           Recente
# 838                      BUDI01 GAMING  Indonesia      319           Recente
# 879                             Vilmei  Indonesia     1324            Antigo
# 902                      Calon Sarjana  Indonesia       29           Recente
# 921                   The Shiny Peanut  Indonesia     2337           Recente
# 976                     SAAIHALILINTAR  Indonesia      409            Antigo
#
#     subscribers_for_last_30_days         category
# 117                    5500000.0    Entertainment
# 129                    1900000.0   People & Blogs
# 159                         ZERO    Entertainment
# 221                     600000.0            Music
# 230                     100000.0   People & Blogs
# 240                     100000.0    Entertainment
# 351                     100000.0   People & Blogs
# 369                          1.0    Entertainment
# 383                     100000.0        Education
# 390                     200000.0           Gaming
# 459                    1600000.0   People & Blogs
# 465                         ZERO   People & Blogs
# 472                         ZERO    Entertainment
# 499                     100000.0   People & Blogs
# 530                     100000.0    Entertainment
# 546                     100000.0    Entertainment
# 591                         ZERO    Entertainment
# 615                     100000.0   People & Blogs
# 645                         ZERO   People & Blogs
# 662                     100000.0        Education
# 689                     100000.0  News & Politics
# 694                     100000.0    Entertainment
# 787                     400000.0    Entertainment
# 838                         ZERO           Gaming
# 879                     800000.0              NaN
# 902                     300000.0    Entertainment
# 921                         ZERO        Education
# 976                         ZERO    Entertainment
# <Axes: xlabel='count', ylabel='category'>

# %%
cat_Vietnam = df2[(df2['country'] == 'Vietnam')]
print(cat_Vietnam)

sns.countplot(cat_Vietnam, y='category')
# Out:
#             youtuber  country  uploads isantigoourecente  \
# 489  Like Nastya VNM  Vietnam      602           Recente
# 585        POPS Kids  Vietnam     3943            Antigo
# 827            FAPTV  Vietnam      863            Antigo
#
#     subscribers_for_last_30_days       category
# 489                     100000.0  Entertainment
# 585                     200000.0          Music
# 827                         ZERO         Comedy
# <Axes: xlabel='count', ylabel='category'>

# %%
cat_Jordania = df2[(df2['country'] == 'Jordan')]
print(cat_Jordania)

sns.countplot(cat_Jordania, y='category')
# Out:
#                                           youtuber country  uploads  \
# 165  ýýýýýýýý ýýýýýýýý ýýýýýýýýýý | toyoraljanahtv  Jordan     3254
# 300                                    toyorbabytv  Jordan     1159
# 803                               karameeshchannel  Jordan     2254
#
#     isantigoourecente subscribers_for_last_30_days       category
# 165            Antigo                     100000.0  Entertainment
# 300            Antigo                     300000.0          Music
# 803            Antigo                     100000.0  Entertainment
# <Axes: xlabel='count', ylabel='category'>

# %%
cat_PB = df2[(df2['country'] == 'Netherlands')]
print(cat_PB)

sns.countplot(cat_PB, y='category')
# Out:
#              youtuber      country  uploads isantigoourecente  \
# 167  Spinnin' Records  Netherlands    11501            Antigo
# 773   NikkieTutorials  Netherlands      876            Antigo
# 816     ýýýýýýýý/Atro  Netherlands     1952           Recente
#
#     subscribers_for_last_30_days       category
# 167                     100000.0          Music
# 773                         ZERO  Howto & Style
# 816                     200000.0         Gaming
# <Axes: xlabel='count', ylabel='category'>

# %%
cat_Singapura = df2[(df2['country'] == 'Singapore')]
print(cat_Singapura)

sns.countplot(cat_Singapura, y='category')
# Out:
#                youtuber    country  uploads isantigoourecente  \
# 190  Sandeep Maheshwari  Singapore        0            Antigo
# 587                LEGO  Singapore    31889            Antigo
# 619           MY FAMILY  Singapore      150           Recente
#
#     subscribers_for_last_30_days        category
# 190                          1.0  People & Blogs
# 587                     200000.0   Entertainment
# 619                        800.0             NaN
# <Axes: xlabel='count', ylabel='category'>

# %%
cat_Suiça = df2[(df2['country'] == 'Sweden')]
print(cat_Indonesia)

sns.countplot(cat_Suiça, y='category')
# Out:
#                               youtuber    country  uploads isantigoourecente  \
# 117                      Jess No Limit  Indonesia     2284           Recente
# 129                     Ricis Official  Indonesia     2736           Recente
# 159                                 AH  Indonesia     2197            Antigo
# 221                           Indosiar  Indonesia    65286            Antigo
# 230                 Rans Entertainment  Indonesia     3716           Recente
# 240                    TRANS7 OFFICIAL  Indonesia    89179            Antigo
# 351                         Baim Paula  Indonesia     2325           Recente
# 369                    Deddy Corbuzier  Indonesia       15            Antigo
# 383  BabyBus - Cerita & Lagu Anak-anak  Indonesia      875           Recente
# 390                            MiawAug  Indonesia     3713            Antigo
# 459                       Willie Salim  Indonesia      679            Antigo
# 465        Naisa Alifia Yuriza (N.A.Y)  Indonesia      786           Recente
# 472                     GEN HALILINTAR  Indonesia     1037           Recente
# 499                         tanboy kun  Indonesia      739           Recente
# 530                  TRANS TV Official  Indonesia   148225            Antigo
# 546                    Like Nastya IDN  Indonesia      502           Recente
# 591                        Dyland PROS  Indonesia     2805           Recente
# 615                      Arif muhammad  Indonesia      542           Recente
# 645                  Kerajinan 5-Menit  Indonesia     4186           Recente
# 662                     Daftar Populer  Indonesia     3810           Recente
# 689                           KOMPASTV  Indonesia   269050            Antigo
# 694                     MNCTV OFFICIAL  Indonesia    66362            Antigo
# 787                     Yudist Ardhana  Indonesia     2854           Recente
# 838                      BUDI01 GAMING  Indonesia      319           Recente
# 879                             Vilmei  Indonesia     1324            Antigo
# 902                      Calon Sarjana  Indonesia       29           Recente
# 921                   The Shiny Peanut  Indonesia     2337           Recente
# 976                     SAAIHALILINTAR  Indonesia      409            Antigo
#
#     subscribers_for_last_30_days         category
# 117                    5500000.0    Entertainment
# 129                    1900000.0   People & Blogs
# 159                         ZERO    Entertainment
# 221                     600000.0            Music
# 230                     100000.0   People & Blogs
# 240                     100000.0    Entertainment
# 351                     100000.0   People & Blogs
# 369                          1.0    Entertainment
# 383                     100000.0        Education
# 390                     200000.0           Gaming
# 459                    1600000.0   People & Blogs
# 465                         ZERO   People & Blogs
# 472                         ZERO    Entertainment
# 499                     100000.0   People & Blogs
# 530                     100000.0    Entertainment
# 546                     100000.0    Entertainment
# 591                         ZERO    Entertainment
# 615                     100000.0   People & Blogs
# 645                         ZERO   People & Blogs
# 662                     100000.0        Education
# 689                     100000.0  News & Politics
# 694                     100000.0    Entertainment
# 787                     400000.0    Entertainment
# 838                         ZERO           Gaming
# 879                     800000.0              NaN
# 902                     300000.0    Entertainment
# 921                         ZERO        Education
# 976                         ZERO    Entertainment
# <Axes: xlabel='count', ylabel='category'>
